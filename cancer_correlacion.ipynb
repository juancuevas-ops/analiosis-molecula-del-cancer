# %% [markdown]
# <a href="https://colab.research.google.com/github/juancuevas-ops/analiosis-molecula-del-cancer/blob/main/cancer_correlacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv
# Leer el Data-Set
df = pd.read_csv("/content/breast-cancer-wisconsin.data")
#Visualizar n registros del Data-Set
df.head(7)
# Out:
#    1000025  5   1  1.1  1.2  2 1.3  3  1.4  1.5  2.1
# 0  1002945  5   4    4    5  7  10  3    2    1    2
# 1  1015425  3   1    1    1  2   2  3    1    1    2
# 2  1016277  6   8    8    1  3   4  3    7    1    2
# 3  1017023  4   1    1    3  2   1  3    1    1    2
# 4  1017122  8  10   10    8  7  10  9    7    1    4
# 5  1018099  1   1    1    1  2  10  3    1    1    2
# 6  1018561  2   1    2    1  2   1  3    1    1    2

# %%
df.shape
# Out:
# (698, 11)

# %%
df.dtypes
# Out:
# 1000025     int64
# 5           int64
# 1           int64
# 1.1         int64
# 1.2         int64
# 2           int64
# 1.3        object
# 3           int64
# 1.4         int64
# 1.5         int64
# 2.1         int64
# dtype: object

# %%
#Contando los datos vacios (NaN, NAN, na)
df.isna().sum()
# Out:
# 1000025    0
# 5          0
# 1          0
# 1.1        0
# 1.2        0
# 2          0
# 1.3        0
# 3          0
# 1.4        0
# 1.5        0
# 2.1        0
# dtype: int64

# %%
# !pip install tensorflow
#Importar librer´ıa para la manipulaci´on de datos
import numpy as np
#Importar librer´ıa para la manipulaci´on de los datos
import pandas as pd
#Importar librer´ıa para la visualizaci´on de datos
import matplotlib.pyplot as plt
#Importar librer´ıa para la visualizaci´on de datos estadisticos
import seaborn as sns
#Importar librer´ıa para pre-procesar datos
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/content/breast-cancer-wisconsin.data")
# Agrupar los valores de la columna indicada y sumarlos
df["1000025"	].value_counts()
# Out:
# 1182404    6
# 1276091    5
# 1198641    3
# 466906     2
# 1116116    2
#           ..
# 1302428    1
# 857774     1
# 1181356    1
# 1125035    1
# 625201     1
# Name: 1000025, Length: 644, dtype: int64

# %%
# !pip install sklearn
#Importar librer´ıa para la manipulaci´on de datos
import numpy as np
#Importar librer´ıa para la manipulaci´on de los datos
import pandas as pd
#Importar librer´ıa para la visualizaci´on de datos
import matplotlib.pyplot as plt
#Importar librer´ıa para la visualizaci´on de datos estadisticos
import seaborn as sns
#Importar librer´ıa para pre-procesar datos
from sklearn import linear_model

# %%
sns_plot = sns.countplot(df["1000025"],label="Count")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Visualizaci´on gr´afico de correlaci´on cruzada
sns_plot = sns.pairplot(df, hue="1000025", height=2.5)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Visualizaci´on gr´afico de calor
plt.figure(figsize=(20,20))
sns_plot = sns.heatmap(df.corr(), annot=True, fmt=".0%")
